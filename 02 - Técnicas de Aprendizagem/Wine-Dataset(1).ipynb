# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

# %%
class WineClassifier(nn.Module) :
    def __init__(self, input_size = 13, hidden_size1=130, hidden_size2 = 70, hidden_size3 = 40, hidden_size4=13, output_size = 3) :
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)
        self.fc4 = nn.Linear(hidden_size3, hidden_size4)
        self.output = nn.Linear(hidden_size4, output_size)
        self.relu = nn.ReLU()

    def forward(self, data) :
        data = self.relu(self.fc1(data))
        data = self.relu(self.fc2(data))
        data = self.relu(self.fc3(data))
        data = self.relu(self.fc4(data))
        data = self.output(data)
        return data

# %%
class DataSet(torch.utils.data.Dataset):
    def __init__(self,data,labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self,idx):
        return self.data[idx], self.labels[idx]

# %%
# Introdução e Tratamento de Dados
inputData = pd.read_csv("wine.data")
data = inputData[inputData.columns[1:]].to_numpy()
labelsTemp = inputData[inputData.columns[0]].to_numpy()
labels = []
for i in range(len(labelsTemp)):
    labels.append(labelsTemp[i] - 1)


data_train, data_test, labels_train, labels_test = train_test_split(data, labels, test_size=0.2, shuffle=True, random_state=41)
data_train, data_validation, labels_train, labels_validation = train_test_split(data_train, labels_train, test_size=0.1, shuffle=True, random_state=41)

dataset = DataSet(data_train,labels_train)
data_train = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=0)

dataset = DataSet(data_validation,labels_validation)
data_validation = DataLoader(dataset, batch_size=len(data_validation), shuffle=True, num_workers=0)

dataset = DataSet(data_test,labels_test)
data_test = DataLoader(dataset, batch_size=len(data_test), shuffle=True, num_workers=0)

# %%
net = WineClassifier()
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# %%
from sklearn.metrics import accuracy_score

# %%
def train_one_epoch(NeuralNet,Loss,Optimizer,data_train):
    NeuralNet.train()
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0

    for i,data in enumerate(data_train):
        x,y = data
        x = x.to(torch.float)
        Optimizer.zero_grad()
        output = NeuralNet(x)
        loss = Loss(output,y)
        loss.backward()
        Optimizer.step()
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
def validation_one_epoch(NeuralNet,Loss, data_validation):
    NeuralNet.train(False)
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0
    for i,data in enumerate(data_validation):
        x,y = data
        x = x.to(torch.float)
        output = NeuralNet(x)
        loss = Loss(output,y)
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
epochs = 200
train_loss_all_epoch = []
train_accuracy_all_epoch = []
val_loss_all_epoch = []
val_accuracy_all_epoch = []
best_val_loss = 1e9

for epoch in range(epochs):
    train_loss_per_epoch, train_accuracy_per_epoch = train_one_epoch(net,loss_function,optimizer,data_train)

    train_loss_all_epoch.append(train_loss_per_epoch)
    train_accuracy_all_epoch.append(train_accuracy_per_epoch)

    val_loss_per_epoch,val_accuracy_per_epoch = validation_one_epoch(net,loss_function, data_validation)

    val_loss_all_epoch.append(val_loss_per_epoch)
    val_accuracy_all_epoch.append(val_accuracy_per_epoch)

    if val_loss_per_epoch < best_val_loss:
        best_val_loss = val_loss_per_epoch
        model_path = 'SaveModels/test_model'
        torch.save(net.state_dict(),model_path)

    if(epoch % 10 == 0) :
      print(f'Epóca [: {epoch}]')
      print(f'Erro de Treinamento: {train_loss_per_epoch}')
      print(f'Erro de Validação: {val_loss_per_epoch}')
      print(f'Acurácia de Treinamento: {train_accuracy_per_epoch}')
      print(f'Acurácia de Validação: {val_accuracy_per_epoch}')
      print()
# Out:
# Epóca [: 0]
# Erro de Treinamento: 2.099887788295746
# Erro de Validação: 0.95879065990448
# Acurácia de Treinamento: 0.3333333432674408
# Acurácia de Validação: 0.46666666865348816
#
# Epóca [: 10]
# Erro de Treinamento: 0.8183611184358597
# Erro de Validação: 0.6895725131034851
# Acurácia de Treinamento: 0.6190476417541504
# Acurácia de Validação: 0.7333333492279053
#
# Epóca [: 20]
# Erro de Treinamento: 0.6634874045848846
# Erro de Validação: 0.5738769769668579
# Acurácia de Treinamento: 0.6507936716079712
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 30]
# Erro de Treinamento: 0.6278274655342102
# Erro de Validação: 0.625728964805603
# Acurácia de Treinamento: 0.658730149269104
# Acurácia de Validação: 0.7333333492279053
#
# Epóca [: 40]
# Erro de Treinamento: 0.6104296743869781
# Erro de Validação: 0.5717877149581909
# Acurácia de Treinamento: 0.7301587462425232
# Acurácia de Validação: 0.7333333492279053
#
# Epóca [: 50]
# Erro de Treinamento: 0.5872975066304207
# Erro de Validação: 0.5756458640098572
# Acurácia de Treinamento: 0.6746031641960144
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 60]
# Erro de Treinamento: 0.582939863204956
# Erro de Validação: 0.5719173550605774
# Acurácia de Treinamento: 0.6984127163887024
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 70]
# Erro de Treinamento: 0.570385292172432
# Erro de Validação: 0.5845510363578796
# Acurácia de Treinamento: 0.6984127163887024
# Acurácia de Validação: 0.7333333492279053
#
# Epóca [: 80]
# Erro de Treinamento: 0.5417883098125458
# Erro de Validação: 0.5639895796775818
# Acurácia de Treinamento: 0.7777777910232544
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 90]
# Erro de Treinamento: 0.4645036309957504
# Erro de Validação: 0.46802690625190735
# Acurácia de Treinamento: 0.841269850730896
# Acurácia de Validação: 0.7333333492279053
#
# Epóca [: 100]
# Erro de Treinamento: 0.41329360008239746
# Erro de Validação: 0.41289207339286804
# Acurácia de Treinamento: 0.8809523582458496
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 110]
# Erro de Treinamento: 0.36712639033794403
# Erro de Validação: 0.36984312534332275
# Acurácia de Treinamento: 0.8492063283920288
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 120]
# Erro de Treinamento: 0.7334576994180679
# Erro de Validação: 0.38758617639541626
# Acurácia de Treinamento: 0.7301587462425232
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 130]
# Erro de Treinamento: 0.25948164612054825
# Erro de Validação: 0.3665327727794647
# Acurácia de Treinamento: 0.9047619104385376
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 140]
# Erro de Treinamento: 0.20916737988591194
# Erro de Validação: 0.320546418428421
# Acurácia de Treinamento: 0.9285714030265808
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 150]
# Erro de Treinamento: 0.18517779558897018
# Erro de Validação: 0.32191091775894165
# Acurácia de Treinamento: 0.9285714030265808
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 160]
# Erro de Treinamento: 0.2014162354171276
# Erro de Validação: 0.29412493109703064
# Acurácia de Treinamento: 0.9285714030265808
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 170]
# Erro de Treinamento: 0.22981461882591248
# Erro de Validação: 0.2744460701942444
# Acurácia de Treinamento: 0.9285714030265808
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 180]
# Erro de Treinamento: 0.23548060841858387
# Erro de Validação: 0.2762056589126587
# Acurácia de Treinamento: 0.9047619104385376
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 190]
# Erro de Treinamento: 0.1969153042882681
# Erro de Validação: 0.30312079191207886
# Acurácia de Treinamento: 0.9365079402923584
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 200]
# Erro de Treinamento: 0.13696405291557312
# Erro de Validação: 0.27924805879592896
# Acurácia de Treinamento: 0.9523809552192688
# Acurácia de Validação: 0.9333333373069763
#
# Epóca [: 210]
# Erro de Treinamento: 0.13988943211734295
# Erro de Validação: 0.2784721255302429
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 220]
# Erro de Treinamento: 0.1719728261232376
# Erro de Validação: 0.26656538248062134
# Acurácia de Treinamento: 0.9285714030265808
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 230]
# Erro de Treinamento: 0.165626872330904
# Erro de Validação: 0.3106417655944824
# Acurácia de Treinamento: 0.9285714030265808
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 240]
# Erro de Treinamento: 0.12558130733668804
# Erro de Validação: 0.29861247539520264
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 250]
# Erro de Treinamento: 0.14052343741059303
# Erro de Validação: 0.2754284143447876
# Acurácia de Treinamento: 0.9365079402923584
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 260]
# Erro de Treinamento: 0.11552471946924925
# Erro de Validação: 0.29205217957496643
# Acurácia de Treinamento: 0.9365079402923584
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 270]
# Erro de Treinamento: 0.10570919699966908
# Erro de Validação: 0.35012155771255493
# Acurácia de Treinamento: 0.9523809552192688
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 280]
# Erro de Treinamento: 0.1266321148723364
# Erro de Validação: 0.2535608112812042
# Acurácia de Treinamento: 0.9365079402923584
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 290]
# Erro de Treinamento: 0.36677831783890724
# Erro de Validação: 1.0983797311782837
# Acurácia de Treinamento: 0.8571428656578064
# Acurácia de Validação: 0.6666666865348816
#
# Epóca [: 300]
# Erro de Treinamento: 0.19390792213380337
# Erro de Validação: 0.29468822479248047
# Acurácia de Treinamento: 0.9365079402923584
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 310]
# Erro de Treinamento: 0.12787571176886559
# Erro de Validação: 0.2723626494407654
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 320]
# Erro de Treinamento: 0.10279373545199633
# Erro de Validação: 0.2856844365596771
# Acurácia de Treinamento: 0.9682539701461792
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 330]
# Erro de Treinamento: 0.11377803049981594
# Erro de Validação: 0.29136669635772705
# Acurácia de Treinamento: 0.9523809552192688
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 340]
# Erro de Treinamento: 0.22266534715890884
# Erro de Validação: 0.30110040307044983
# Acurácia de Treinamento: 0.9126983880996704
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 350]
# Erro de Treinamento: 0.1328933984041214
# Erro de Validação: 0.3056083619594574
# Acurácia de Treinamento: 0.9365079402923584
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 360]
# Erro de Treinamento: 0.10428020358085632
# Erro de Validação: 0.30033665895462036
# Acurácia de Treinamento: 0.9523809552192688
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 370]
# Erro de Treinamento: 0.10651238542050123
# Erro de Validação: 0.28681623935699463
# Acurácia de Treinamento: 0.9682539701461792
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 380]
# Erro de Treinamento: 0.08602788439020514
# Erro de Validação: 0.29198014736175537
# Acurácia de Treinamento: 0.976190447807312
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 390]
# Erro de Treinamento: 0.10105923935770988
# Erro de Validação: 0.27444469928741455
# Acurácia de Treinamento: 0.976190447807312
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 400]
# Erro de Treinamento: 0.07555675180628896
# Erro de Validação: 0.30942437052726746
# Acurácia de Treinamento: 0.9841269850730896
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 410]
# Erro de Treinamento: 0.07713905908167362
# Erro de Validação: 0.2835320234298706
# Acurácia de Treinamento: 0.9841269850730896
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 420]
# Erro de Treinamento: 0.12890199944376945
# Erro de Validação: 0.3502759337425232
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 430]
# Erro de Treinamento: 0.08887878758832812
# Erro de Validação: 0.2829801142215729
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 440]
# Erro de Treinamento: 0.1857508309185505
# Erro de Validação: 0.3182757794857025
# Acurácia de Treinamento: 0.89682537317276
# Acurácia de Validação: 0.9333333373069763
#
# Epóca [: 450]
# Erro de Treinamento: 0.07675796141847968
# Erro de Validação: 0.34617555141448975
# Acurácia de Treinamento: 0.9841269850730896
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 460]
# Erro de Treinamento: 0.12112231459468603
# Erro de Validação: 0.38265180587768555
# Acurácia de Treinamento: 0.9603174328804016
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 470]
# Erro de Treinamento: 0.06430839188396931
# Erro de Validação: 0.25108224153518677
# Acurácia de Treinamento: 0.9920634627342224
# Acurácia de Validação: 0.8666666746139526
#
# Epóca [: 480]
# Erro de Treinamento: 0.08892643242143095
# Erro de Validação: 0.35905301570892334
# Acurácia de Treinamento: 0.9523809552192688
# Acurácia de Validação: 0.800000011920929
#
# Epóca [: 490]
# Erro de Treinamento: 0.076081826351583
# Erro de Validação: 0.2511497437953949
# Acurácia de Treinamento: 0.9603174328804016
# Acurácia de Validação: 0.8666666746139526

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss_all_epoch)
plt.plot(val_loss_all_epoch)
plt.legend(['Treino', 'Validação'])
plt.xlabel('Épocas')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracy_all_epoch)
plt.plot(val_accuracy_all_epoch)
plt.legend(['Treino', 'Validação'])
plt.xlabel('Épocas')

plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix

net.train(False)
for data in data_test:
    x_test, y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)
    c_matrix = confusion_matrix(y_test, y_pred, labels=range(3))

c_matrix
# Out:
# array([[ 9,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  0, 15]])

# %%
from sklearn.metrics import classification_report

net.train(False)

for data in data_test:
    x_test,y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)

    print(classification_report(y_test,y_pred,zero_division=1))
# Out:
# tensor([2, 1, 2, 2, 2, 0, 1, 2, 1, 0, 2, 0, 1, 2, 1, 1, 2, 0, 1, 2, 2, 0, 2, 1,
#         0, 1, 0, 0, 2, 1, 0, 1, 2, 2, 1, 2])
# tensor([2, 1, 2, 2, 2, 0, 1, 2, 1, 0, 2, 0, 1, 2, 1, 1, 2, 0, 1, 2, 2, 0, 2, 1,
#         0, 1, 0, 0, 2, 1, 0, 1, 2, 2, 1, 2])
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
