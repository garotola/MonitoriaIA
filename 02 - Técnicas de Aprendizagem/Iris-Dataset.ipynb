# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

# %%
# Importar os dados
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
print(f"Base de dados com {len(df)} linhas")
# Out:
# Base de dados com 150 linhas

# %%
# Alterando dados categóricos para numéricos
df['variety'] = df['variety'].replace('Setosa', 0)
df['variety'] = df['variety'].replace('Versicolor', 1)
df['variety'] = df['variety'].replace('Virginica', 2)
df['variety']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: variety, Length: 150, dtype: int64

# %%
# Principio do Aprendizado de Maquina Supervisionado
data = df.drop('variety', axis=1) # Dados
labels = df['variety'] # Labels

# %%
# csv -> dados
data = data.values
labels = labels.values

# %%
# Dividindo dados para o processo de treino, teste e validação
from sklearn.model_selection import train_test_split
data_train, data_test, labels_train, labels_test = train_test_split(data, labels,
                                                                    test_size=0.2, random_state=41)
data_train, data_validation, labels_train, labels_validation = train_test_split(data_train, labels_train,
                                                                                test_size=0.1,
                                                                                random_state=1)
#https://justpaste.it/cf7rw
print(f'Quantidade de Dados para Treinamento : {len(data_train)}')
print(f'Quantidade de Dados para Validação : {len(data_test)}')
print(f'Quantidade de Dados para Teste : {len(data_validation)}')
# Out:
# Quantidade de Dados para Treinamento : 108
# Quantidade de Dados para Validação : 30
# Quantidade de Dados para Teste : 12

# %%
class DataSet(torch.utils.data.Dataset):
    def __init__(self,data,labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self,idx):
        return self.data[idx], self.labels[idx]

# %%
dataset = DataSet(data_train,labels_train)
data_train = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=0)

dataset = DataSet(data_validation,labels_validation)
data_validation = DataLoader(dataset, batch_size=len(data_validation), shuffle=True, num_workers=0)

dataset = DataSet(data_test,labels_test)
data_test = DataLoader(dataset, batch_size=len(data_test), shuffle=True, num_workers=0)

# %%
# Importação das Bibliotecas
import torch.nn as nn

# Criação do Modelo de Rede
    # 4 Entradas (4 Caracteristicas da Flor)
    # 2 Camadas de Neuronio
    # 3 Saidas (3 Rotulos de Flor)
class IrisClassifier(nn.Module) :
    def __init__(self, input_size = 4, hidden_size1=20, hidden_size2 = 10, output_size = 3) :
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.output = nn.Linear(hidden_size2, output_size)
        self.relu = nn.ReLU()

    def forward(self, data) :
        data = self.relu(self.fc1(data))
        data = self.relu(self.fc2(data))
        data = self.output(data)
        return data

# %%
net = IrisClassifier()
learning_rate = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
def train_one_epoch(model,loss_function,optimizer,data_train):
    model.train()
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0

    for i,data in enumerate(data_train):
        x,y = data
        x = x.to(torch.float)
        optimizer.zero_grad()
        output = model(x)
        loss = loss_function(output,y)
        loss.backward()
        optimizer.step()
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
def validation_one_epoch(model,loss_function, data_validation):
    model.train(False)
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0
    for i,data in enumerate(data_validation):
        x,y = data
        x = x.to(torch.float)
        output = model(x)
        loss = loss_function(output,y)
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
epochs = 1000
train_loss_all_epoch = []
train_accuracy_all_epoch = []
val_loss_all_epoch = []
val_accuracy_all_epoch = []
best_val_loss = 1e9

for epoch in range(epochs):

    train_loss_per_epoch, train_accuracy_per_epoch = train_one_epoch(net,criterion,optimizer,data_train)

    train_loss_all_epoch.append(train_loss_per_epoch)
    train_accuracy_all_epoch.append(train_accuracy_per_epoch)

    val_loss_per_epoch,val_accuracy_per_epoch = validation_one_epoch(net,criterion, data_validation)

    val_loss_all_epoch.append(val_loss_per_epoch)
    val_accuracy_all_epoch.append(val_accuracy_per_epoch)

    if val_loss_per_epoch < best_val_loss:
        best_val_loss = val_loss_per_epoch
        model_path = 'test_model'
        torch.save(net.state_dict(),model_path)

    if(epoch % 1 == 0) :
      print(f'Epóca [: {epoch}]')
      print(f'Erro de Treinamento: {train_loss_per_epoch}')
      print(f'Erro de Validação: {val_loss_per_epoch}')
      print(f'Acurácia de Treinamento: {train_accuracy_per_epoch}')
      print(f'Acurácia de Validação: {val_accuracy_per_epoch}')
      print()
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Acurácia de Validação: 1.0
#
# Epóca [: 167]
# Erro de Treinamento: 0.02938514156267047
# Erro de Validação: 0.002005618065595627
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 168]
# Erro de Treinamento: 0.022220480313990265
# Erro de Validação: 0.0007154099293984473
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 169]
# Erro de Treinamento: 0.027420575264841318
# Erro de Validação: 0.0007103104144334793
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 170]
# Erro de Treinamento: 0.02971867343876511
# Erro de Validação: 0.0010433195857331157
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 171]
# Erro de Treinamento: 0.038466860773041844
# Erro de Validação: 0.0010374461999163032
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 172]
# Erro de Treinamento: 0.06925232522189617
# Erro de Validação: 0.0006435794639401138
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 173]
# Erro de Treinamento: 0.04354734905064106
# Erro de Validação: 0.006553663406521082
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 174]
# Erro de Treinamento: 0.03771734144538641
# Erro de Validação: 0.0006272994796745479
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 175]
# Erro de Treinamento: 0.052156983874738216
# Erro de Validação: 0.000721879827324301
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 176]
# Erro de Treinamento: 0.03150528494734317
# Erro de Validação: 0.0028122880030423403
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 177]
# Erro de Treinamento: 0.048641496687196195
# Erro de Validação: 0.0007641867850907147
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 178]
# Erro de Treinamento: 0.03990535717457533
# Erro de Validação: 0.001203926862217486
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 179]
# Erro de Treinamento: 0.053774203232023865
# Erro de Validação: 0.0013298867270350456
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 180]
# Erro de Treinamento: 0.05659629171714187
# Erro de Validação: 0.0019173385808244348
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 181]
# Erro de Treinamento: 0.07522536721080542
# Erro de Validação: 0.0007155214552767575
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 182]
# Erro de Treinamento: 0.031191356014460325
# Erro de Validação: 0.0037279108073562384
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 183]
# Erro de Treinamento: 0.048525120597332716
# Erro de Validação: 0.0011946250451728702
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 184]
# Erro de Treinamento: 0.03875411534681916
# Erro de Validação: 0.0005817515193484724
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 185]
# Erro de Treinamento: 0.023701498095761053
# Erro de Validação: 0.001832163892686367
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 186]
# Erro de Treinamento: 0.03336904337629676
# Erro de Validação: 0.0011435103369876742
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 187]
# Erro de Treinamento: 0.02257932786596939
# Erro de Validação: 0.0008300721528939903
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 188]
# Erro de Treinamento: 0.02471326178056188
# Erro de Validação: 0.0007972751627676189
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 189]
# Erro de Treinamento: 0.02290994266513735
# Erro de Validação: 0.0006187756080180407
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 190]
# Erro de Treinamento: 0.04426230222452432
# Erro de Validação: 0.0008268998353742063
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 191]
# Erro de Treinamento: 0.09803633484989405
# Erro de Validação: 0.0011309859110042453
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 192]
# Erro de Treinamento: 0.01715662586502731
# Erro de Validação: 0.009368732571601868
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 193]
# Erro de Treinamento: 0.1363559581222944
# Erro de Validação: 0.0005483764689415693
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 194]
# Erro de Treinamento: 0.04509271087590605
# Erro de Validação: 0.0036723027005791664
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 195]
# Erro de Treinamento: 0.03541736793704331
# Erro de Validação: 0.0005181879387237132
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 196]
# Erro de Treinamento: 0.03466500143986195
# Erro de Validação: 0.0005669425008818507
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 197]
# Erro de Treinamento: 0.021293213358148932
# Erro de Validação: 0.0011045013088732958
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 198]
# Erro de Treinamento: 0.024219686398282647
# Erro de Validação: 0.0011044067796319723
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 199]
# Erro de Treinamento: 0.023629687260836363
# Erro de Validação: 0.0007769307703711092
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 200]
# Erro de Treinamento: 0.025926043512299657
# Erro de Validação: 0.000685260456521064
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 201]
# Erro de Treinamento: 0.023138585151173174
# Erro de Validação: 0.0006073706317692995
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 202]
# Erro de Treinamento: 0.020450524461921304
# Erro de Validação: 0.000991647015325725
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 203]
# Erro de Treinamento: 0.02757953992113471
# Erro de Validação: 0.0007000582409091294
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 204]
# Erro de Treinamento: 0.041481312713585794
# Erro de Validação: 0.0005269116954877973
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 205]
# Erro de Treinamento: 0.02054512919858098
# Erro de Validação: 0.0017093423521146178
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 206]
# Erro de Treinamento: 0.030790330143645406
# Erro de Validação: 0.0006723487749695778
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 207]
# Erro de Treinamento: 0.021626382134854794
# Erro de Validação: 0.0004801190225407481
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 208]
# Erro de Treinamento: 0.023121201375033706
# Erro de Validação: 0.0009269832517020404
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 209]
# Erro de Treinamento: 0.025419190002139658
# Erro de Validação: 0.0007495401077903807
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 210]
# Erro de Treinamento: 0.0205392578500323
# Erro de Validação: 0.0005143777234479785
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 211]
# Erro de Treinamento: 0.02073284678044729
# Erro de Validação: 0.0006940032471902668
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 212]
# Erro de Treinamento: 0.01885857281740755
# Erro de Validação: 0.0007895664894022048
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 213]
# Erro de Treinamento: 0.026022930222097784
# Erro de Validação: 0.0005890191532671452
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 214]
# Erro de Treinamento: 0.020415750885149464
# Erro de Validação: 0.0004326881607994437
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 215]
# Erro de Treinamento: 0.027707144850865006
# Erro de Validação: 0.0008542481809854507
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 216]
# Erro de Treinamento: 0.026430682512000203
# Erro de Validação: 0.0006154091097414494
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 217]
# Erro de Treinamento: 0.019434577436186373
# Erro de Validação: 0.000469043618068099
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 218]
# Erro de Treinamento: 0.021903280867263675
# Erro de Validação: 0.0007850111578591168
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 219]
# Erro de Treinamento: 0.023540982976555824
# Erro de Validação: 0.0009414904634468257
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 220]
# Erro de Treinamento: 0.019496604218147695
# Erro de Validação: 0.00047134284977801144
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 221]
# Erro de Treinamento: 0.02298852428793907
# Erro de Validação: 0.0005098874098621309
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 222]
# Erro de Treinamento: 0.021246449556201696
# Erro de Validação: 0.0005806675180792809
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 223]
# Erro de Treinamento: 0.03301199697307311
# Erro de Validação: 0.0006835772655904293
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 224]
# Erro de Treinamento: 0.023700155783444643
# Erro de Validação: 0.0013003736967220902
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 225]
# Erro de Treinamento: 0.030139028647681698
# Erro de Validação: 0.0004886955139227211
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 226]
# Erro de Treinamento: 0.020605233759852126
# Erro de Validação: 0.0008235276327468455
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 227]
# Erro de Treinamento: 0.021032623248174787
# Erro de Validação: 0.0005025370628573
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 228]
# Erro de Treinamento: 0.0188704854081152
# Erro de Validação: 0.000403563492000103
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 229]
# Erro de Treinamento: 0.020483040127146523
# Erro de Validação: 0.0006948211812414229
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 230]
# Erro de Treinamento: 0.02105107545503415
# Erro de Validação: 0.0006821947754360735
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 231]
# Erro de Treinamento: 0.03494191251229495
# Erro de Validação: 0.00048568329657427967
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 232]
# Erro de Treinamento: 0.03066798025975004
# Erro de Validação: 0.0007561658858321607
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 233]
# Erro de Treinamento: 0.026133158011361957
# Erro de Validação: 0.0003488443326205015
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 234]
# Erro de Treinamento: 0.01835928481159499
# Erro de Validação: 0.0008473689667880535
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 235]
# Erro de Treinamento: 0.04042721621226519
# Erro de Validação: 0.0008791815489530563
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 236]
# Erro de Treinamento: 0.020807769033126533
# Erro de Validação: 0.0010049539851024747
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 237]
# Erro de Treinamento: 0.020737116050440818
# Erro de Validação: 0.0003515130083542317
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 238]
# Erro de Treinamento: 0.022823790553957224
# Erro de Validação: 0.0003463852044660598
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 239]
# Erro de Treinamento: 0.026530783041380346
# Erro de Validação: 0.0005950126214884222
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 240]
# Erro de Treinamento: 0.03319820063188672
# Erro de Validação: 0.0007353541441261768
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 241]
# Erro de Treinamento: 0.020246389700332657
# Erro de Validação: 0.00030999479349702597
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 242]
# Erro de Treinamento: 0.034640917321667075
# Erro de Validação: 0.000411823159083724
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 243]
# Erro de Treinamento: 0.03202613668690901
# Erro de Validação: 0.0006414912058971822
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 244]
# Erro de Treinamento: 0.019278030609712005
# Erro de Validação: 0.00030009361216798425
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 245]
# Erro de Treinamento: 0.030938679235987365
# Erro de Validação: 0.0003971271216869354
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 246]
# Erro de Treinamento: 0.03837402956560254
# Erro de Validação: 0.000708221981767565
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 247]
# Erro de Treinamento: 0.029211762492195703
# Erro de Validação: 0.00026368515682406723
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 248]
# Erro de Treinamento: 0.032281889056321234
# Erro de Validação: 0.000504087598528713
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 249]
# Erro de Treinamento: 0.047965943114832044
# Erro de Validação: 0.0003936068678740412
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 250]
# Erro de Treinamento: 0.05397535779775353
# Erro de Validação: 0.0003512590192258358
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 251]
# Erro de Treinamento: 0.03296542912721634
# Erro de Validação: 0.0010749519569799304
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 252]
# Erro de Treinamento: 0.03871184925083071
# Erro de Validação: 0.001316901296377182
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 253]
# Erro de Treinamento: 0.01869487042131368
# Erro de Validação: 0.0002497468376532197
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 254]
# Erro de Treinamento: 0.03677838340081507
# Erro de Validação: 0.00029938507941551507
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 255]
# Erro de Treinamento: 0.03057359205558896
# Erro de Validação: 0.0007052102591842413
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 256]
# Erro de Treinamento: 0.02237879297172185
# Erro de Validação: 0.0002710875996854156
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 257]
# Erro de Treinamento: 0.029341474059037864
# Erro de Validação: 0.0005594518152065575
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 258]
# Erro de Treinamento: 0.04877901641884819
# Erro de Validação: 0.0004469378909561783
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 259]
# Erro de Treinamento: 0.03161077424738323
# Erro de Validação: 0.0002596840786281973
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 260]
# Erro de Treinamento: 0.04603841481730342
# Erro de Validação: 0.0005610741791315377
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 261]
# Erro de Treinamento: 0.031771766720339656
# Erro de Validação: 0.0003997284220531583
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 262]
# Erro de Treinamento: 0.022288911513896892
# Erro de Validação: 0.0006665242835879326
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 263]
# Erro de Treinamento: 0.019331100513227284
# Erro de Validação: 0.0002676690637599677
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 264]
# Erro de Treinamento: 0.023477004608139396
# Erro de Validação: 0.000246435753069818
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 265]
# Erro de Treinamento: 0.018399804597720504
# Erro de Validação: 0.0008585284813307226
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 266]
# Erro de Treinamento: 0.022862752892251592
# Erro de Validação: 0.00040040144813247025
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 267]
# Erro de Treinamento: 0.028240853142051492
# Erro de Validação: 0.00025368164642713964
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 268]
# Erro de Treinamento: 0.01920302482903935
# Erro de Validação: 0.0006709881708957255
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 269]
# Erro de Treinamento: 0.0191150123719126
# Erro de Validação: 0.00034084278740920126
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 270]
# Erro de Treinamento: 0.058609541156329215
# Erro de Validação: 0.00048026497825048864
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 271]
# Erro de Treinamento: 0.0350626427680254
# Erro de Validação: 0.0027428411412984133
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 272]
# Erro de Treinamento: 0.037066712306113914
# Erro de Validação: 0.00028159882640466094
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 273]
# Erro de Treinamento: 0.07026553398463875
# Erro de Validação: 0.00021633593132719398
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 274]
# Erro de Treinamento: 0.01816214865539223
# Erro de Validação: 0.0016122114611789584
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 275]
# Erro de Treinamento: 0.040777853748295456
# Erro de Validação: 0.0002803640381898731
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 276]
# Erro de Treinamento: 0.015620775186107494
# Erro de Validação: 0.00020894379122182727
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 277]
# Erro de Treinamento: 0.02841378835728392
# Erro de Validação: 0.0003597597824409604
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 278]
# Erro de Treinamento: 0.015922093225526623
# Erro de Validação: 0.000816847023088485
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 279]
# Erro de Treinamento: 0.026009068824350834
# Erro de Validação: 0.0003104122879449278
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 280]
# Erro de Treinamento: 0.018739528924925253
# Erro de Validação: 0.0003212346928194165
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 281]
# Erro de Treinamento: 0.0210481530521065
# Erro de Validação: 0.00025869812816381454
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 282]
# Erro de Treinamento: 0.027173305876203813
# Erro de Validação: 0.00027685274835675955
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 283]
# Erro de Treinamento: 0.025050558644579723
# Erro de Validação: 0.00024651954299770296
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 284]
# Erro de Treinamento: 0.020028379512950778
# Erro de Validação: 0.00041410737321712077
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 285]
# Erro de Treinamento: 0.01756482059136033
# Erro de Validação: 0.0007114919717423618
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 286]
# Erro de Treinamento: 0.029672431061044335
# Erro de Validação: 0.0003358201065566391
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 287]
# Erro de Treinamento: 0.028308447217568755
# Erro de Validação: 0.0003754737845156342
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 288]
# Erro de Treinamento: 0.01919132146576885
# Erro de Validação: 0.000202783674467355
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 289]
# Erro de Treinamento: 0.027355597529094666
# Erro de Validação: 0.0003775880904868245
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 290]
# Erro de Treinamento: 0.018050919723464176
# Erro de Validação: 0.0003554219438228756
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 291]
# Erro de Treinamento: 0.016741161540267058
# Erro de Validação: 0.0003132097190245986
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 292]
# Erro de Treinamento: 0.020890353072900325
# Erro de Validação: 0.000286593014607206
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 293]
# Erro de Treinamento: 0.016659197535773274
# Erro de Validação: 0.0003082419279962778
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 294]
# Erro de Treinamento: 0.022361274110153317
# Erro de Validação: 0.00029395640012808144
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 295]
# Erro de Treinamento: 0.041083069518208504
# Erro de Validação: 0.00023785827215760946
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 296]
# Erro de Treinamento: 0.016723363427445292
# Erro de Validação: 0.001090400037355721
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 297]
# Erro de Treinamento: 0.03033672971650958
# Erro de Validação: 0.00029550676117651165
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 298]
# Erro de Treinamento: 0.015366797211754601
# Erro de Validação: 0.0002528402837924659
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 299]
# Erro de Treinamento: 0.016035619428294012
# Erro de Validação: 0.0002992991067003459
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 300]
# Erro de Treinamento: 0.016658320208080113
# Erro de Validação: 0.0003034294059034437
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 301]
# Erro de Treinamento: 0.021223068644758314
# Erro de Validação: 0.00030194103601388633
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 302]
# Erro de Treinamento: 0.017013779404805973
# Erro de Validação: 0.00033477318356744945
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 303]
# Erro de Treinamento: 0.02178415097296238
# Erro de Validação: 0.00026638174313120544
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 304]
# Erro de Treinamento: 0.01809600880369544
# Erro de Validação: 0.00035632980871014297
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 305]
# Erro de Treinamento: 0.016266524809907423
# Erro de Validação: 0.00028892644331790507
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 306]
# Erro de Treinamento: 0.017236614134162664
# Erro de Validação: 0.0002405739651294425
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 307]
# Erro de Treinamento: 0.016608127123618033
# Erro de Validação: 0.0002919959370046854
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 308]
# Erro de Treinamento: 0.015119840194529388
# Erro de Validação: 0.00036023263237439096
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 309]
# Erro de Treinamento: 0.026231752708554268
# Erro de Validação: 0.00021450838539749384
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 310]
# Erro de Treinamento: 0.020883392891846597
# Erro de Validação: 0.00016603647964075208
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 311]
# Erro de Treinamento: 0.03239661734551191
# Erro de Validação: 0.00039565085899084806
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 312]
# Erro de Treinamento: 0.020279963908251375
# Erro de Validação: 0.0001887744147097692
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 313]
# Erro de Treinamento: 0.023911425261758268
# Erro de Validação: 0.00020463061810005456
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 314]
# Erro de Treinamento: 0.017648554872721434
# Erro de Validação: 0.00018042568990495056
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 315]
# Erro de Treinamento: 0.01812662552401889
# Erro de Validação: 0.00022739573614671826
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 316]
# Erro de Treinamento: 0.015391620341688395
# Erro de Validação: 0.00026137178065255284
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 317]
# Erro de Treinamento: 0.029140232523786835
# Erro de Validação: 0.00022343698947224766
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 318]
# Erro de Treinamento: 0.022866837953188224
# Erro de Validação: 0.00015085196355357766
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 319]
# Erro de Treinamento: 0.018617706540680956
# Erro de Validação: 0.00036859395913779736
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 320]
# Erro de Treinamento: 0.020948105491697788
# Erro de Validação: 0.0003515143471304327
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 321]
# Erro de Treinamento: 0.015850587078602985
# Erro de Validação: 0.0001699876884231344
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 322]
# Erro de Treinamento: 0.024988286313600838
# Erro de Validação: 0.00020854662579949945
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 323]
# Erro de Treinamento: 0.016639984198263846
# Erro de Validação: 0.00020145229063928127
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 324]
# Erro de Treinamento: 0.01536315999692306
# Erro de Validação: 0.0002253968414152041
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 325]
# Erro de Treinamento: 0.021206727484241128
# Erro de Validação: 0.0002558090491220355
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 326]
# Erro de Treinamento: 0.02145123522495851
# Erro de Validação: 0.00033214411814697087
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 327]
# Erro de Treinamento: 0.03205179545329884
# Erro de Validação: 0.00018361858383286744
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 328]
# Erro de Treinamento: 0.01299741863476811
# Erro de Validação: 0.00041944615077227354
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 329]
# Erro de Treinamento: 0.025258177454816177
# Erro de Validação: 0.0001649404875934124
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 330]
# Erro de Treinamento: 0.02597046224400401
# Erro de Validação: 0.00013016583397984505
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 331]
# Erro de Treinamento: 0.01973877215277753
# Erro de Validação: 0.0004275756946299225
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 332]
# Erro de Treinamento: 0.01905394995083043
# Erro de Validação: 0.00040013063699007034
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 333]
# Erro de Treinamento: 0.023828202127333498
# Erro de Validação: 0.00012668965791817755
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 334]
# Erro de Treinamento: 0.02012243086937815
# Erro de Validação: 0.0002404769038548693
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 335]
# Erro de Treinamento: 0.015940533572575077
# Erro de Validação: 0.0002401291421847418
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 336]
# Erro de Treinamento: 0.01700449059717357
# Erro de Validação: 0.00014418168575502932
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 337]
# Erro de Treinamento: 0.02350129885599017
# Erro de Validação: 0.0001882047508843243
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 338]
# Erro de Treinamento: 0.019403223392146174
# Erro de Validação: 0.00031620144727639854
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 339]
# Erro de Treinamento: 0.018859037925722077
# Erro de Validação: 0.00013701349962502718
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 340]
# Erro de Treinamento: 0.04452905555081088
# Erro de Validação: 0.0001246722531504929
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 341]
# Erro de Treinamento: 0.012681633932515979
# Erro de Validação: 0.0006582203786820173
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 342]
# Erro de Treinamento: 0.05769464874174446
# Erro de Validação: 0.00013508608390111476
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 343]
# Erro de Treinamento: 0.1360721681267023
# Erro de Validação: 0.0002154818648705259
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 344]
# Erro de Treinamento: 0.0913301739783492
# Erro de Validação: 0.03600075840950012
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 345]
# Erro de Treinamento: 0.13283231551395147
# Erro de Validação: 0.00013612728798761964
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 346]
# Erro de Treinamento: 0.06637696723919362
# Erro de Validação: 0.00016354249964933842
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 347]
# Erro de Treinamento: 0.04741455061594024
# Erro de Validação: 0.0006897262646816671
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 348]
# Erro de Treinamento: 0.02501159891107818
# Erro de Validação: 0.00017987443425226957
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 349]
# Erro de Treinamento: 0.021694387747629662
# Erro de Validação: 0.00010205103899352252
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 350]
# Erro de Treinamento: 0.019228370452765375
# Erro de Validação: 0.0003745907451957464
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 351]
# Erro de Treinamento: 0.03242682048585266
# Erro de Validação: 0.00016522449732292444
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 352]
# Erro de Treinamento: 0.022731909339199774
# Erro de Validação: 0.00010399019811302423
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 353]
# Erro de Treinamento: 0.040367061796132475
# Erro de Validação: 0.00018068309873342514
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 354]
# Erro de Treinamento: 0.016533811896806583
# Erro de Validação: 0.00012510499800555408
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 355]
# Erro de Treinamento: 0.015453979780431837
# Erro de Validação: 0.00022402733156923205
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 356]
# Erro de Treinamento: 0.022273170863627456
# Erro de Validação: 0.00020507024601101875
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 357]
# Erro de Treinamento: 0.0211410338524729
# Erro de Validação: 0.00011479280510684475
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 358]
# Erro de Treinamento: 0.02347697748336941
# Erro de Validação: 0.0001871820422820747
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 359]
# Erro de Treinamento: 0.013980378051201114
# Erro de Validação: 0.00023315286671277136
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 360]
# Erro de Treinamento: 0.014412232005270198
# Erro de Validação: 0.00016663788119331002
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 361]
# Erro de Treinamento: 0.015106730192201212
# Erro de Validação: 0.00017108563042711467
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 362]
# Erro de Treinamento: 0.015554969431832433
# Erro de Validação: 0.00019183405674993992
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 363]
# Erro de Treinamento: 0.013847675305441953
# Erro de Validação: 0.0003149530093651265
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 364]
# Erro de Treinamento: 0.01949553721351549
# Erro de Validação: 0.00017081158875953406
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 365]
# Erro de Treinamento: 0.03981000231578946
# Erro de Validação: 0.0001526895648567006
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 366]
# Erro de Treinamento: 0.0538748218677938
# Erro de Validação: 0.0006936823483556509
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 367]
# Erro de Treinamento: 0.03405827429378405
# Erro de Validação: 0.00012170596892246976
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 368]
# Erro de Treinamento: 0.022483550215838477
# Erro de Validação: 0.00042314687743782997
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 369]
# Erro de Treinamento: 0.026096147834323347
# Erro de Validação: 0.00026895091286860406
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 370]
# Erro de Treinamento: 0.015034175619803136
# Erro de Validação: 0.0001371026737615466
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 371]
# Erro de Treinamento: 0.01992724927549716
# Erro de Validação: 0.00015317289216909558
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 372]
# Erro de Treinamento: 0.01936346669390332
# Erro de Validação: 0.00016259112453553826
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 373]
# Erro de Treinamento: 0.014024142525158823
# Erro de Validação: 0.0002899021783377975
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 374]
# Erro de Treinamento: 0.020267915446311235
# Erro de Validação: 0.00018200185149908066
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 375]
# Erro de Treinamento: 0.019389259861782193
# Erro de Validação: 0.00012527832586783916
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 376]
# Erro de Treinamento: 0.015201977308606729
# Erro de Validação: 0.00029680118313990533
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 377]
# Erro de Treinamento: 0.019432678238445078
# Erro de Validação: 0.00017344886146020144
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 378]
# Erro de Treinamento: 0.03693467387347482
# Erro de Validação: 0.0001593464839970693
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 379]
# Erro de Treinamento: 0.02003906955360435
# Erro de Validação: 0.0004550647281575948
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 380]
# Erro de Treinamento: 0.018481988576240838
# Erro de Validação: 0.00012618109758477658
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 381]
# Erro de Treinamento: 0.02358489186190127
# Erro de Validação: 0.00011834681936306879
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 382]
# Erro de Treinamento: 0.015033025934826583
# Erro de Validação: 0.00025061931228265166
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 383]
# Erro de Treinamento: 0.0195188197249081
# Erro de Validação: 0.00022197479847818613
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 384]
# Erro de Treinamento: 0.013690490224689711
# Erro de Validação: 0.00012937738210894167
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 385]
# Erro de Treinamento: 0.01589522196445614
# Erro de Validação: 0.0001697150873951614
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 386]
# Erro de Treinamento: 0.017783264978788793
# Erro de Validação: 0.00018604735669214278
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 387]
# Erro de Treinamento: 0.02380221348721534
# Erro de Validação: 0.00018480856670066714
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 388]
# Erro de Treinamento: 0.024373354157432914
# Erro de Validação: 0.0002133193629560992
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 389]
# Erro de Treinamento: 0.03369227924849838
# Erro de Validação: 0.0001288711791858077
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 390]
# Erro de Treinamento: 0.043844070976774674
# Erro de Validação: 0.00014280945470090955
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 391]
# Erro de Treinamento: 0.08652326022274792
# Erro de Validação: 0.00011859688675031066
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 392]
# Erro de Treinamento: 0.013905981671996415
# Erro de Validação: 0.0031466048676520586
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 393]
# Erro de Treinamento: 0.13181850186083466
# Erro de Validação: 0.00016034365398809314
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 394]
# Erro de Treinamento: 0.056119694010703824
# Erro de Validação: 0.00045435436186380684
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 395]
# Erro de Treinamento: 0.0781359231332317
# Erro de Validação: 0.00022859811724629253
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 396]
# Erro de Treinamento: 0.09898090113711078
# Erro de Validação: 0.0006143385544419289
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 397]
# Erro de Treinamento: 0.055149813124444336
# Erro de Validação: 0.00010753575043054298
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 398]
# Erro de Treinamento: 0.02520479925442487
# Erro de Validação: 0.0004417443124111742
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 399]
# Erro de Treinamento: 0.02336465218104422
# Erro de Validação: 0.00029280094895511866
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 400]
# Erro de Treinamento: 0.014770651869184803
# Erro de Validação: 9.607285755919293e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 401]
# Erro de Treinamento: 0.027505192323587835
# Erro de Validação: 0.00012025627074763179
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 402]
# Erro de Treinamento: 0.014622458023950458
# Erro de Validação: 0.0005194087862037122
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 403]
# Erro de Treinamento: 0.05132816475816071
# Erro de Validação: 0.00014321603521239012
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 404]
# Erro de Treinamento: 0.0342899051393033
# Erro de Validação: 0.00015196605818346143
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 405]
# Erro de Treinamento: 0.06798138777958229
# Erro de Validação: 0.00023280976165551692
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 406]
# Erro de Treinamento: 0.03777859499678016
# Erro de Validação: 0.016980482265353203
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 407]
# Erro de Treinamento: 0.08937333372887224
# Erro de Validação: 0.00011495212675072253
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 408]
# Erro de Treinamento: 0.042342691973317415
# Erro de Validação: 0.00020549411419779062
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 409]
# Erro de Treinamento: 0.0549594167387113
# Erro de Validação: 0.00021519565780181438
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 410]
# Erro de Treinamento: 0.16495743684936315
# Erro de Validação: 0.000298988918075338
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 411]
# Erro de Treinamento: 0.06918707652948797
# Erro de Validação: 0.006623938679695129
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 412]
# Erro de Treinamento: 0.2267540517495945
# Erro de Validação: 0.00012815829541068524
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 413]
# Erro de Treinamento: 0.34572675300296396
# Erro de Validação: 0.05472470447421074
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 414]
# Erro de Treinamento: 0.18737147492356598
# Erro de Validação: 0.004569018725305796
# Acurácia de Treinamento: 0.9351851940155029
# Acurácia de Validação: 1.0
#
# Epóca [: 415]
# Erro de Treinamento: 0.21300903451628983
# Erro de Validação: 0.004283223766833544
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 416]
# Erro de Treinamento: 0.09764192627335433
# Erro de Validação: 0.0009253504103980958
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 417]
# Erro de Treinamento: 0.04472017101943493
# Erro de Validação: 0.010018804110586643
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 418]
# Erro de Treinamento: 0.07233610656112432
# Erro de Validação: 0.001193225965835154
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 419]
# Erro de Treinamento: 0.016746308145229705
# Erro de Validação: 0.0009913063840940595
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 420]
# Erro de Treinamento: 0.05760168097913265
# Erro de Validação: 0.0009326317231170833
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 421]
# Erro de Treinamento: 0.02519898710306734
# Erro de Validação: 0.0017972345231100917
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 422]
# Erro de Treinamento: 0.046375874895602465
# Erro de Validação: 0.003480863757431507
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 423]
# Erro de Treinamento: 0.033149104565382004
# Erro de Validação: 0.0010866299271583557
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 424]
# Erro de Treinamento: 0.021234913845546544
# Erro de Validação: 0.0009252354502677917
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 425]
# Erro de Treinamento: 0.03545580361969769
# Erro de Validação: 0.00097028719028458
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 426]
# Erro de Treinamento: 0.03936928231269121
# Erro de Validação: 0.00206687836907804
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 427]
# Erro de Treinamento: 0.02334838401293382
# Erro de Validação: 0.0008984669111669064
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 428]
# Erro de Treinamento: 0.01844448373594787
# Erro de Validação: 0.0007303734892047942
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 429]
# Erro de Treinamento: 0.022158954379847273
# Erro de Validação: 0.0007921711076050997
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 430]
# Erro de Treinamento: 0.01551848417147994
# Erro de Validação: 0.0010849910322576761
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 431]
# Erro de Treinamento: 0.026850634021684527
# Erro de Validação: 0.0009319547098129988
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 432]
# Erro de Treinamento: 0.020408261101692915
# Erro de Validação: 0.0010083512170240283
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 433]
# Erro de Treinamento: 0.021901417640037835
# Erro de Validação: 0.0006584582733921707
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 434]
# Erro de Treinamento: 0.06079112715087831
# Erro de Validação: 0.0005537317483685911
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 435]
# Erro de Treinamento: 0.01916042430093512
# Erro de Validação: 0.003501729341223836
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 436]
# Erro de Treinamento: 0.06311680958606303
# Erro de Validação: 0.0010686729801818728
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 437]
# Erro de Treinamento: 0.02169803879223764
# Erro de Validação: 0.0004720283905044198
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 438]
# Erro de Treinamento: 0.05437105958117172
# Erro de Validação: 0.0004549860314000398
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 439]
# Erro de Treinamento: 0.06710186426062137
# Erro de Validação: 0.0011265281355008483
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 440]
# Erro de Treinamento: 0.02160916614229791
# Erro de Validação: 0.0004322569293435663
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 441]
# Erro de Treinamento: 0.03730159404221922
# Erro de Validação: 0.0004217935202177614
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 442]
# Erro de Treinamento: 0.016841438598930836
# Erro de Validação: 0.0007753074169158936
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 443]
# Erro de Treinamento: 0.02576497416885104
# Erro de Validação: 0.001112313475459814
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 444]
# Erro de Treinamento: 0.02162852816400118
# Erro de Validação: 0.0004596630169544369
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 445]
# Erro de Treinamento: 0.019498691988701466
# Erro de Validação: 0.0004052361473441124
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 446]
# Erro de Treinamento: 0.02645471040159464
# Erro de Validação: 0.0005148099735379219
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 447]
# Erro de Treinamento: 0.031881477450951934
# Erro de Validação: 0.0007364474586211145
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 448]
# Erro de Treinamento: 0.033903783885762095
# Erro de Validação: 0.0004139769298490137
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 449]
# Erro de Treinamento: 0.01936357480008155
# Erro de Validação: 0.0006386447348631918
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 450]
# Erro de Treinamento: 0.01674760808236897
# Erro de Validação: 0.0004997414071112871
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 451]
# Erro de Treinamento: 0.019540451699867845
# Erro de Validação: 0.0004101759986951947
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 452]
# Erro de Treinamento: 0.030527207418344915
# Erro de Validação: 0.00038569499156437814
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 453]
# Erro de Treinamento: 0.019731212814804167
# Erro de Validação: 0.0007543691317550838
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 454]
# Erro de Treinamento: 0.023816485889256
# Erro de Validação: 0.0005335715250112116
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 455]
# Erro de Treinamento: 0.018317167880013585
# Erro de Validação: 0.00033046407043002546
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 456]
# Erro de Treinamento: 0.01891935564344749
# Erro de Validação: 0.00033688265830278397
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 457]
# Erro de Treinamento: 0.02104024302389007
# ...
# Acurácia de Validação: 1.0
#
# Epóca [: 900]
# Erro de Treinamento: 0.017983213663683273
# Erro de Validação: 0.0001261079014511779
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 901]
# Erro de Treinamento: 0.011452959428424947
# Erro de Validação: 0.00010829441453097388
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 902]
# Erro de Treinamento: 0.015085934966919012
# Erro de Validação: 0.00010796658898470923
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 903]
# Erro de Treinamento: 0.019834706879919395
# Erro de Validação: 0.00011012065078830346
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 904]
# Erro de Treinamento: 0.012545584970212076
# Erro de Validação: 9.67045416473411e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 905]
# Erro de Treinamento: 0.012776152016158449
# Erro de Validação: 0.00011164735769852996
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 906]
# Erro de Treinamento: 0.015162395298830234
# Erro de Validação: 0.00010664189903764054
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 907]
# Erro de Treinamento: 0.009223782526532887
# Erro de Validação: 0.00010148800356546417
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 908]
# Erro de Treinamento: 0.009567357250489295
# Erro de Validação: 8.962207357399166e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 909]
# Erro de Treinamento: 0.009933485998772085
# Erro de Validação: 8.933383651310578e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 910]
# Erro de Treinamento: 0.008387250471059815
# Erro de Validação: 8.890643221093342e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 911]
# Erro de Treinamento: 0.010260023398586782
# Erro de Validação: 8.445759885944426e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 912]
# Erro de Treinamento: 0.018696504659601487
# Erro de Validação: 8.966064342530444e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 913]
# Erro de Treinamento: 0.02115486991533544
# Erro de Validação: 8.571852958993986e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 914]
# Erro de Treinamento: 0.012788573745638132
# Erro de Validação: 6.524097989313304e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 915]
# Erro de Treinamento: 0.026692030296544544
# Erro de Validação: 8.726698433747515e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 916]
# Erro de Treinamento: 0.01570134093708475
# Erro de Validação: 9.305545972893015e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 917]
# Erro de Treinamento: 0.00908472589799203
# Erro de Validação: 7.294747047126293e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 918]
# Erro de Treinamento: 0.010473705406184308
# Erro de Validação: 7.311623630812392e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 919]
# Erro de Treinamento: 0.01350151636870578
# Erro de Validação: 7.445690425811335e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 920]
# Erro de Treinamento: 0.008813414453470614
# Erro de Validação: 7.378160808002576e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 921]
# Erro de Treinamento: 0.011576496261113789
# Erro de Validação: 7.7654498454649e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 922]
# Erro de Treinamento: 0.008561813388951123
# Erro de Validação: 8.1815873272717e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 923]
# Erro de Treinamento: 0.01709038198168855
# Erro de Validação: 7.762553286738694e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 924]
# Erro de Treinamento: 0.012191038855235092
# Erro de Validação: 6.748551822965965e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 925]
# Erro de Treinamento: 0.01637161907274276
# Erro de Validação: 7.71882914705202e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 926]
# Erro de Treinamento: 0.008942311600549147
# Erro de Validação: 7.658221875317395e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 927]
# Erro de Treinamento: 0.009800627445656573
# Erro de Validação: 7.736689440207556e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 928]
# Erro de Treinamento: 0.00851875013904646
# Erro de Validação: 7.203406130429357e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 929]
# Erro de Treinamento: 0.01909884937776951
# Erro de Validação: 7.722796726739034e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 930]
# Erro de Treinamento: 0.014207154519681353
# Erro de Validação: 9.363219578517601e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 931]
# Erro de Treinamento: 0.014914653076630202
# Erro de Validação: 6.638299237238243e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 932]
# Erro de Treinamento: 0.02582134390831925
# Erro de Validação: 6.470444350270554e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 933]
# Erro de Treinamento: 0.019662150400108658
# Erro de Validação: 7.647275924682617e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 934]
# Erro de Treinamento: 0.007997367167263292
# Erro de Validação: 6.32343944744207e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 935]
# Erro de Treinamento: 0.012705599423497915
# Erro de Validação: 6.455530092353001e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 936]
# Erro de Treinamento: 0.011224885543924756
# Erro de Validação: 7.375152927124873e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 937]
# Erro de Treinamento: 0.011057592858378484
# Erro de Validação: 6.508169462904334e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 938]
# Erro de Treinamento: 0.008761347482504789
# Erro de Validação: 6.869673234177753e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 939]
# Erro de Treinamento: 0.00775391364004463
# Erro de Validação: 6.785260484321043e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 940]
# Erro de Treinamento: 0.008622776005722699
# Erro de Validação: 6.676011980744079e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 941]
# Erro de Treinamento: 0.00791540486170561
# Erro de Validação: 6.676998600596562e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 942]
# Erro de Treinamento: 0.011230442987653078
# Erro de Validação: 6.515112181659788e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 943]
# Erro de Treinamento: 0.009013601167680463
# Erro de Validação: 5.789085116703063e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 944]
# Erro de Treinamento: 0.010055820879642852
# Erro de Validação: 6.321437831502408e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 945]
# Erro de Treinamento: 0.010014770527050132
# Erro de Validação: 6.611427670577541e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 946]
# Erro de Treinamento: 0.008284168890895671
# Erro de Validação: 5.971829887130298e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 947]
# Erro de Treinamento: 0.018146296941267792
# Erro de Validação: 6.063194086891599e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 948]
# Erro de Treinamento: 0.0068100705539109185
# Erro de Validação: 9.812606003833935e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 949]
# Erro de Treinamento: 0.03262176318094134
# Erro de Validação: 6.016533370711841e-05
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 950]
# Erro de Treinamento: 0.03227615193463862
# Erro de Validação: 5.7046428992180154e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 951]
# Erro de Treinamento: 0.006564714029082097
# Erro de Validação: 8.411830640397966e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 952]
# Erro de Treinamento: 0.021648469231877243
# Erro de Validação: 5.869534288649447e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 953]
# Erro de Treinamento: 0.018019259066932136
# Erro de Validação: 5.523888466996141e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 954]
# Erro de Treinamento: 0.014076660478167469
# Erro de Validação: 6.886474875500426e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 955]
# Erro de Treinamento: 0.013198086176998913
# Erro de Validação: 5.568576671066694e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 956]
# Erro de Treinamento: 0.008849045173519698
# Erro de Validação: 5.0222963182022795e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 957]
# Erro de Treinamento: 0.013493183636455797
# Erro de Validação: 5.7304550864500925e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 958]
# Erro de Treinamento: 0.00815521035110578
# Erro de Validação: 6.390881753759459e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 959]
# Erro de Treinamento: 0.010487921841559
# Erro de Validação: 5.3858169849263504e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 960]
# Erro de Treinamento: 0.011249966435570968
# Erro de Validação: 5.09480269101914e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 961]
# Erro de Treinamento: 0.011146522345370613
# Erro de Validação: 5.704627255909145e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 962]
# Erro de Treinamento: 0.012384713110805023
# Erro de Validação: 6.2915678427089e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 963]
# Erro de Treinamento: 0.011617131356615573
# Erro de Validação: 5.402698297984898e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 964]
# Erro de Treinamento: 0.024611138040199876
# Erro de Validação: 5.2408100600587204e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 965]
# Erro de Treinamento: 0.006905431000632234
# Erro de Validação: 9.178149775834754e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 966]
# Erro de Treinamento: 0.03016933954495471
# Erro de Validação: 5.3937677876092494e-05
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 967]
# Erro de Treinamento: 0.014784653001697734
# Erro de Validação: 4.998423901270144e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 968]
# Erro de Treinamento: 0.021049328075605445
# Erro de Validação: 6.748429586878046e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 969]
# Erro de Treinamento: 0.017592991793208057
# Erro de Validação: 6.0085480072302744e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 970]
# Erro de Treinamento: 0.007412939141431707
# Erro de Validação: 4.811721373698674e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 971]
# Erro de Treinamento: 0.03423448232933879
# Erro de Validação: 5.435467392089777e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 972]
# Erro de Treinamento: 0.02631696828393615
# Erro de Validação: 8.392633753828704e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 973]
# Erro de Treinamento: 0.023402212471410166
# Erro de Validação: 4.438254109118134e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 974]
# Erro de Treinamento: 0.01835022508385009
# Erro de Validação: 5.144441092852503e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 975]
# Erro de Treinamento: 0.019724417164070474
# Erro de Validação: 5.9359732404118404e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 976]
# Erro de Treinamento: 0.008201025309972465
# Erro de Validação: 4.542545138974674e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 977]
# Erro de Treinamento: 0.009905912605972844
# Erro de Validação: 4.4322940084384754e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 978]
# Erro de Treinamento: 0.01328637101687491
# Erro de Validação: 5.287448948365636e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 979]
# Erro de Treinamento: 0.008080927807895932
# Erro de Validação: 4.690536661655642e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 980]
# Erro de Treinamento: 0.010285100899636745
# Erro de Validação: 4.9706330173648894e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 981]
# Erro de Treinamento: 0.011334612987411674
# Erro de Validação: 4.8951547796605155e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 982]
# Erro de Treinamento: 0.010815714726049919
# Erro de Validação: 5.0898310291813686e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 983]
# Erro de Treinamento: 0.009161720096017234
# Erro de Validação: 5.5417414841940627e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 984]
# Erro de Treinamento: 0.009948348888428882
# Erro de Validação: 5.251733819022775e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 985]
# Erro de Treinamento: 0.0080928453053275
# Erro de Validação: 5.616250564344227e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 986]
# Erro de Treinamento: 0.007153134572035924
# Erro de Validação: 5.549706474994309e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 987]
# Erro de Treinamento: 0.0069813822283322224
# Erro de Validação: 5.395753760240041e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 988]
# Erro de Treinamento: 0.007772245172418479
# Erro de Validação: 5.334171873982996e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 989]
# Erro de Treinamento: 0.009081221360247582
# Erro de Validação: 5.32423728145659e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 990]
# Erro de Treinamento: 0.007762001769151539
# Erro de Validação: 5.0123566325055435e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 991]
# Erro de Treinamento: 0.007381635128695052
# Erro de Validação: 5.079897528048605e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 992]
# Erro de Treinamento: 0.007232058699628396
# Erro de Validação: 5.0918140914291143e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 993]
# Erro de Treinamento: 0.009687647598184412
# Erro de Validação: 4.903097578790039e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 994]
# Erro de Treinamento: 0.007529184491431806
# Erro de Validação: 4.538568828138523e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 995]
# Erro de Treinamento: 0.008456641357042827
# Erro de Validação: 4.815690408577211e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 996]
# Erro de Treinamento: 0.007190780645032646
# Erro de Validação: 4.7481487854383886e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 997]
# Erro de Treinamento: 0.016438251550425775
# Erro de Validação: 5.129553028382361e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 998]
# Erro de Treinamento: 0.01151434626444825
# Erro de Validação: 5.6758046412141994e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 999]
# Erro de Treinamento: 0.013753465842455626
# Erro de Validação: 4.4610835175262764e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0

# %%
import matplotlib.pyplot as plt

plt.plot(train_loss_all_epoch)
plt.plot(val_loss_all_epoch)
plt.legend(['Treino', 'Validação'])
plt.xlabel('Épocas')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_accuracy_all_epoch)
plt.plot(val_accuracy_all_epoch)
plt.legend(['Treino', 'Validação'])
plt.xlabel('Épocas')

plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix

net.train(False)
for data in data_test:
    x_test, y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)
    c_matrix = confusion_matrix(y_test, y_pred, labels=range(3))

c_matrix
# Out:
# array([[ 9,  0,  0],
#        [ 0, 10,  1],
#        [ 0,  1,  9]])

# %%
from sklearn.metrics import classification_report

net.train(False)

for data in data_test:
    x_test,y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)

    print(classification_report(y_test,y_pred,zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.91      0.91      0.91        11
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.93      0.93      0.93        30

# %%
for data in data_test:
    x_test,y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)

    print(y_test)
    print(y_pred)
# Out:
# tensor([2, 2, 1, 1, 2, 0, 0, 0, 2, 2, 1, 1, 1, 1, 1, 0, 0, 0, 2, 0, 1, 0, 1, 0,
#         2, 1, 2, 2, 2, 1])
# tensor([2, 2, 1, 1, 2, 0, 0, 0, 2, 2, 2, 1, 1, 1, 1, 0, 0, 0, 1, 0, 1, 0, 1, 0,
#         2, 1, 2, 2, 2, 1])
